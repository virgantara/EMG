# %%
import pandas as pd
import numpy as np
import math
from digital_processing import bp_filter, notch_filter, plot_signal
from feature_extraction import features_estimation, time_features_estimation,frequency_features_estimation

# Load data
signal_path = 'dataset1.xlsx'
# nama_sheet='01-gm-ka-1'
# emg_signal = pd.read_excel(io=signal_path,sheet_name=nama_sheet,usecols=[0,1,2,3]).values

features_names = ['VAR', 'RMS', 'IEMG', 'MAV', 'LOG', 'WL', 'ACC', 'DASDV', 'ZC', 'WAMP', 'MYOP', "FR", "MNP", "TP",
                      "MNF", "MDF", "PKF", "WENT"]
df = pd.DataFrame(columns=features_names)
sheets_dict = pd.read_excel(signal_path, sheet_name=None)
list_cols_name = ['barefoot','soft','medium','hard']
for name, sheet in sheets_dict.items():
    sheet['sheet'] = name
    print('Processing Sheet',name)
    nama_sheet = name
    emg_signal = pd.read_excel(io=signal_path,sheet_name=nama_sheet,usecols=[0,1,2,3]).values

    sampling_frequency = 2e3
    frame = 60
    step = 30
    list_cols = [0,1,2,3]
    splitted = nama_sheet.split("-")
    subject = splitted[0]
    otot = splitted[1]
    foot = splitted[2]
    trial = splitted[3]
    for col, col_name in zip(list_cols, list_cols_name):
        print('Processing '+col_name)
        channel_name = col
        signal = emg_signal[:,col]
        signal = signal.reshape((signal.size,))
        filtered_signal = signal
        emg_features, features_names = features_estimation(filtered_signal, channel_name,sampling_frequency, frame, step)
        
        emg_features = emg_features.T
        d = pd.DataFrame(emg_features)
        d['subject'] = subject
        d['otot'] = otot
        d['foot'] = foot
        d['trial'] = trial
        d['class'] = col_name
        df = df.append([d],ignore_index = True)
df.to_csv('joint_features/all.csv')
# Out:
# Processing Sheet 01-gm-ka-1
# Processing barefoot
# (896,)
# Processing soft
# (896,)
# Processing medium
# (896,)
# Processing hard
# (896,)
# Processing Sheet 01-gm-ki-1
# Processing barefoot
# (880,)
# Processing soft
# (880,)
# Processing medium
# (880,)
# Processing hard
# (880,)
# Processing Sheet 01-ta-ka-1
# Processing barefoot
# (880,)
# Processing soft
# (880,)
# Processing medium
# (880,)
# Processing hard
# (880,)
# Processing Sheet 01-ta-ki-1
# Processing barefoot
# (880,)
# Processing soft
# (880,)
# Processing medium
# (880,)
# Processing hard
# (880,)
# Processing Sheet 01-vm-ka-1
# Processing barefoot
# (880,)
# Processing soft
# (880,)
# Processing medium
# (880,)
# Processing hard
# (880,)
# Processing Sheet 01-v-ki-1
# Processing barefoot
# (880,)
# Processing soft
# (880,)
# Processing medium
# (880,)
# Processing hard
# (880,)
# Processing Sheet 02-gm-ka-1
# Processing barefoot
# (832,)
# Processing soft
# (832,)
# Processing medium
# (832,)
# Processing hard
# (832,)
# Processing Sheet 02-gm-ki-1
# Processing barefoot
# (832,)
# Processing soft
# (832,)
# Processing medium
# (832,)
# Processing hard
# (832,)
# Processing Sheet 02-ta-ka-1
# Processing barefoot
# (832,)
# Processing soft
# (832,)
# Processing medium
# (832,)
# Processing hard
# (832,)
# Processing Sheet 02-ta-ki-1
# Processing barefoot
# (832,)
# Processing soft
# (832,)
# Processing medium
# (832,)
# Processing hard
# (832,)
# Processing Sheet 02-vm-ka-1
# Processing barefoot
# (832,)
# Processing soft
# (832,)
# Processing medium
# (832,)
# Processing hard
# (832,)
# Processing Sheet 02-vm-ki-1
# Processing barefoot
# (832,)
# Processing soft
# (832,)
# Processing medium
# (832,)
# Processing hard
# (832,)
# Processing Sheet 03-gm-ka-1
# Processing barefoot
# (944,)
# Processing soft
# (944,)
# Processing medium
# (944,)
# Processing hard
# (944,)
# Processing Sheet 03-gm-ki-1
# Processing barefoot
# (944,)
# Processing soft
# (944,)
# Processing medium
# (944,)
# Processing hard
# (944,)
# Processing Sheet 03-ta-ka-1
# Processing barefoot
# (944,)
# Processing soft
# (944,)
# Processing medium
# (944,)
# Processing hard
# (944,)
# Processing Sheet 03-ta-ki-1
# Processing barefoot
# (944,)
# Processing soft
# (944,)
# Processing medium
# (944,)
# Processing hard
# (944,)
# Processing Sheet 03-vm-ka-1
# Processing barefoot
# (944,)
# Processing soft
# (944,)
# Processing medium
# (944,)
# Processing hard
# (944,)
# Processing Sheet 03-vm-ki-1
# Processing barefoot
# (944,)
# Processing soft
# (944,)
# Processing medium
# (944,)
# Processing hard
# (944,)
# Processing Sheet 04-gm-ka-1
# Processing barefoot
# (1008,)
# Processing soft
# (1008,)
# Processing medium
# (1008,)
# Processing hard
# (1008,)
# Processing Sheet 04-gm-ki-1
# Processing barefoot
# (1008,)
# Processing soft
# (1008,)
# Processing medium
# (1008,)
# Processing hard
# (1008,)
# Processing Sheet 04-ta-ka-1
# Processing barefoot
# (1008,)
# Processing soft
# (1008,)
# Processing medium
# (1008,)
# Processing hard
# (1008,)
# Processing Sheet 04-ta-ki-1
# Processing barefoot
# (1008,)
# Processing soft
# (1008,)
# Processing medium
# (1008,)
# Processing hard
# (1008,)
# Processing Sheet 04-vm-ka-1
# Processing barefoot
# (1008,)
# Processing soft
# (1008,)
# Processing medium
# (1008,)
# Processing hard
# (1008,)
# Processing Sheet 04-vm-ki-1
# Processing barefoot
# (1008,)
# Processing soft
# (1008,)
# Processing medium
# (1008,)
# Processing hard
# (1008,)
# Processing Sheet 05-gm-ka-1
# Processing barefoot
# (1024,)
# Processing soft
# (1024,)
# Processing medium
# (1024,)
# Processing hard
# (1024,)
# Processing Sheet 05-gm-ki-1
# Processing barefoot
# (1024,)
# Processing soft
# (1024,)
# Processing medium
# (1024,)
# Processing hard
# (1024,)
# Processing Sheet 05-ta-ka-1
# Processing barefoot
# (1024,)
# Processing soft
# (1024,)
# Processing medium
# (1024,)
# Processing hard
# (1024,)
# Processing Sheet 05-ta-ki-1
# Processing barefoot
# (1024,)
# Processing soft
# (1024,)
# Processing medium
# (1024,)
# Processing hard
# (1024,)
# Processing Sheet 05-vm-ka-1
# Processing barefoot
# (1024,)
# Processing soft
# (1024,)
# Processing medium
# (1024,)
# Processing hard
# (1024,)
# Processing Sheet 05-vm-ki-1
# Processing barefoot
# (1024,)
# Processing soft
# (1024,)
# Processing medium
# (1024,)
# Processing hard
# (1024,)
# Processing Sheet 06-gm-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 06-gm-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 06-ta-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 06-ta-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 06-vm-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 06-vm-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 07-gm-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 07-gm-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 07-ta-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 07-ta-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 07-vm-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 07-vm-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 08-gm-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 08-gm-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 08-ta-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 08-ta-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 08-vm-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 08-vm-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 09-gm-ka-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 09-gm-ki-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 09-ta-ka-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 09-ta-ki-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 09-vm-ka-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 09-vm-ki-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 10-gm-ka-1
# Processing barefoot
# (896,)
# Processing soft
# (896,)
# Processing medium
# (896,)
# Processing hard
# (896,)
# Processing Sheet 10-gm-ki-1
# Processing barefoot
# (896,)
# Processing soft
# (896,)
# Processing medium
# (896,)
# Processing hard
# (896,)
# Processing Sheet 10-ta-ka-1
# Processing barefoot
# (896,)
# Processing soft
# (896,)
# Processing medium
# (896,)
# Processing hard
# (896,)
# Processing Sheet 10-ta-ki-1
# Processing barefoot
# (896,)
# Processing soft
# (896,)
# Processing medium
# (896,)
# Processing hard
# (896,)
# Processing Sheet 10-vm-ka-1
# Processing barefoot
# (896,)
# Processing soft
# (896,)
# Processing medium
# (896,)
# Processing hard
# (896,)
# Processing Sheet 10-vm-ki-1
# Processing barefoot
# (896,)
# Processing soft
# (896,)
# Processing medium
# (896,)
# Processing hard
# (896,)
# Processing Sheet 11-gm-ka-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 11-gm-ki-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 11-ta-ka-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 11-ta-ki-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 11-vm-ka-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 11-vm-ki-1
# Processing barefoot
# (960,)
# Processing soft
# (960,)
# Processing medium
# (960,)
# Processing hard
# (960,)
# Processing Sheet 12-gm-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 12-gm-ki-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 12-ta-ka-1
# Processing barefoot
# (976,)
# Processing soft
# (976,)
# Processing medium
# (976,)
# Processing hard
# (976,)
# Processing Sheet 12-ta-ki-1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_37766/1828232392.py in <module>
#      19     print('Processing Sheet',name)
#      20     nama_sheet = name
# ---> 21     emg_signal = pd.read_excel(io=signal_path,sheet_name=nama_sheet,usecols=[0,1,2,3]).values
#      22
#      23     sampling_frequency = 2e3
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1231         self.storage_options = storage_options
#    1232
# -> 1233         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1234
#    1235     def __fspath__(self):
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, filepath_or_buffer, storage_options)
#     520         """
#     521         import_optional_dependency("openpyxl")
# --> 522         super().__init__(filepath_or_buffer, storage_options=storage_options)
#     523
#     524     @property
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer, storage_options)
#     418             self.handles.handle.seek(0)
#     419             try:
# --> 420                 self.book = self.load_workbook(self.handles.handle)
#     421             except Exception:
#     422                 self.close()
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/pandas/io/excel/_openpyxl.py in load_workbook(self, filepath_or_buffer)
#     531         from openpyxl import load_workbook
#     532
# --> 533         return load_workbook(
#     534             filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     535         )
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
# --> 317     reader.read()
#     318     return reader.wb
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/openpyxl/reader/excel.py in read(self)
#     280         self.read_theme()
#     281         apply_stylesheet(self.archive, self.wb)
# --> 282         self.read_worksheets()
#     283         self.parser.assign_names()
#     284         if not self.read_only:
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/openpyxl/reader/excel.py in read_worksheets(self)
#     217
#     218             if self.read_only:
# --> 219                 ws = ReadOnlyWorksheet(self.wb, sheet.name, rel.target, self.shared_strings)
#     220                 ws.sheet_state = sheet.state
#     221                 self.wb._sheets.append(ws)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py in __init__(self, parent_workbook, title, worksheet_path, shared_strings)
#      39         self._worksheet_path = worksheet_path
#      40         self._shared_strings = shared_strings
# ---> 41         self._get_size()
#      42
#      43
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py in _get_size(self)
#      45         src = self._get_source()
#      46         parser = WorkSheetParser(src, [])
# ---> 47         dimensions = parser.parse_dimensions()
#      48         src.close()
#      49         if dimensions is not None:
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py in parse_dimensions(self)
#     164         it = iterparse(self.source)
#     165
# --> 166         for _event, element in it:
#     167             if element.tag == DIMENSION_TAG:
#     168                 dim = SheetDimension.from_tree(element)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/xml/etree/ElementTree.py in iterator()
#    1257                 if not data:
#    1258                     break
# -> 1259                 pullparser.feed(data)
#    1260             root = pullparser._close_and_return_root()
#    1261             yield from pullparser.read_events()
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/xml/etree/ElementTree.py in feed(self, data)
#    1299         if data:
#    1300             try:
# -> 1301                 self._parser.feed(data)
#    1302             except SyntaxError as exc:
#    1303                 self._events_queue.append(exc)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/xml/etree/ElementTree.py in feed(self, data)
#    1718         """Feed encoded data to parser."""
#    1719         try:
# -> 1720             self.parser.Parse(data, False)
#    1721         except self._error as v:
#    1722             self._raiseerror(v)
#
# /home/conda/feedstock_root/build_artifacts/python-split_1639967286578/work/Modules/pyexpat.c in EndElement()
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/xml/etree/ElementTree.py in handler(tag, event, append, end)
#    1589                 def handler(tag, event=event_name, append=append,
#    1590                             end=self._end):
# -> 1591                     append((event, end(tag)))
#    1592                 parser.EndElementHandler = handler
#    1593             elif event_name == "start-ns":
#
# ~/anaconda3/envs/tf_gpu/lib/python3.9/xml/etree/ElementTree.py in _end(self, tag)
#    1659
#    1660     def _end(self, tag):
# -> 1661         return self.target.end(self._fixname(tag))
#    1662
#    1663     def _default(self, text):
#
# KeyboardInterrupt:
